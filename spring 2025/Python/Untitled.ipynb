# %%
import pandas as pd
import numpy as np
import statistics as st

# %%
v = np.arange(1,1000) # this creates a vector from 1 to 999

# %%
import random as ran
v1 = ran.choices(v,k=5000)

# %%
import matplotlib.pyplot as plt
plt.hist(v1)
# Out:
# (array([509., 481., 501., 489., 464., 525., 523., 491., 510., 507.]),
#  array([  1. , 100.8, 200.6, 300.4, 400.2, 500. , 599.8, 699.6, 799.4,
#         899.2, 999. ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
sns.kdeplot(v1, fill = 1)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import pymc as pm
